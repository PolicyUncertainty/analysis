# %%
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = "../../daten/output/"

# %%
pd.read_stata(DATA_DIR + "chart_ret_exp_vars_by_education.dta")
# Out:
#     education    gebjahr_group  exp_stop_work_mean  exp_stop_work_SEM
# 0         0.0  1959 and before           71.599998           2.481935  \
# 1         0.0        1960_1969           64.125000           0.548944
# 2         0.0        1970_1979           66.500000           2.872281
# 3         0.0        1980_1989           65.461540           1.677970
# 4         0.0   1990 and above           62.258064           1.033803
# 5         1.0  1959 and before           71.687500           1.076169
# 6         1.0        1960_1969           64.246910           0.309585
# 7         1.0        1970_1979           64.226418           0.536506
# 8         1.0        1980_1989           62.711540           0.690015
# 9         1.0   1990 and above           64.095238           0.904762
# 10        2.0  1959 and before           71.357140           1.636155
# 11        2.0        1960_1969           65.693550           0.531697
# ...
